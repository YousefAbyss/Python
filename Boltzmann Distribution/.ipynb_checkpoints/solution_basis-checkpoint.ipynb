# %% [markdown]
# **Molecular Dynamics simulation routine:**

# %% [markdown]
# this is some text that explains stuff you do.

# %% [markdown]
# * Import external libraries:

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from matplotlib import animation, rc
plt.style.use(['science', 'notebook'])
from IPython.display import HTML
import copy
import numpy as np
import scipy as scy

# %% [markdown]
# * Creating a particle class:

# %%
class Particle:
    def __init__(self, r, x, y, vx, vy):
        self.r = r
        self.x = x
        self.y = y
        self.vx = vx
        self.vy = vy
        
    def __repr__(self):
        return str("This is a particle at %0.2f, %0.2f with v=%0.2f,%0.2f" % (self.x,self.y,self.vx,self.vy))

# %% [markdown]
# * Defining the box:

# %%
box = [20, 20]

# %% [markdown]
# * Initialize velocities:

# %%
vel = 0.5
angle = np.random.uniform(0, 2*np.pi)

# %% [markdown]
# * Initialize position:

# %%
x_rand = np.random.randint(1, box[0]-1, 1)
y_rand = np.random.randint(1, box[1]-1, 1)

# %% [markdown]
# * Setting up the particle:

# %%
p1 = Particle(0.5, x_rand, y_rand, np.sin(angle)*vel, np.cos(angle)*vel)

# %%
p1
# Out:
# This is a particle at 1.00, 6.00 with v=-0.40,0.30

# %% [markdown]
# * Defining simulation step numbers

# %%
steps = 2000

# %% [markdown]
# * initialize trajectory:

# %%
data_traj = np.zeros((4,steps))

# %% [markdown]
# * define time integrator for numerical, stepwise solution of equation of motion with a discrete time step $dt$:

# %%
def move(p,dt):
    p.x = p.x + p.vx*dt
    p.y = p.y + p.vy*dt
    return p

# %% [markdown]
# * define box reflection:

# %%
def reflect(p):
    if (p.x + p.r) >= box[0]:
        p.vx = p.vx * (-1)
    if (p.x - p.r) <= 0:
        p.vx = p.vx * (-1)
    if (p.y + p.r) >= box[1]:
        p.vy = p.vy * (-1)
    if (p.y - p.r) <= 0:
        p.vy = p.vy * (-1)
    return p

# %% [markdown]
# * carry out simulation:

# %%
for i in range(steps):
    reflect(p1)
    move(p1,1)
    data_traj[:,i] = [p1.x, p1.y, p1.vx, p1.vy]
# Out:
# C:\Users\Cirilla\AppData\Local\Temp\ipykernel_6320\2589448372.py:4: DeprecationWarning: setting an array element with a sequence. This was supported in some cases where the elements are arrays with a single element. For example `np.array([1, np.array([2])], dtype=int)`. In the future this will raise the same ValueError as `np.array([1, [2]], dtype=int)`.
#   data_traj[:,i] = [p1.x, p1.y, p1.vx, p1.vy]

# %% [markdown]
# * Plotting trajectory with Matplotlib:

# %%
plt.plot(data_traj[0],data_traj[1],'-')
plt.xlabel('position x')
plt.ylabel('position y')
plt.show()

# %% [markdown]
# **Animate trajectory:**

# %% [markdown]
# * Set up the figure, the axis, and the plot element we want to animate

# %%
fig, ax = plt.subplots()

ax.set_xlim((0, box[0]))
ax.set_ylim((0, box[1]))

plt.xlabel('position x')
plt.ylabel('position y')

dot, = ax.plot([], [], 'bo', ms=5.0)

# %% [markdown]
# * initialization function: plot the background of each frame

# %%
def init():
    dot.set_data([], [])
    return (dot,)

# %% [markdown]
# * animation function. This is called sequentially

# %%
def animate(i):
    x = data_traj[0,i]
    y = data_traj[1,i]
    dot.set_data(x, y)
    return (dot,)

# %% [markdown]
# * call the animator. blit=True means only re-draw the parts that have changed.

# %%
anim = animation.FuncAnimation(fig, animate, init_func=init, frames=300, interval=20, blit=True)

# %%
anim.save('test03.gif',writer='pillow',fps=10,dpi=100)

# %%
HTML(anim.to_html5_video())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Input In [68], in <cell line: 1>()
# ----> 1 HTML(anim.to_html5_video())
#
# File D:\Anaconda\envs\Physics\lib\site-packages\matplotlib\animation.py:1264, in Animation.to_html5_video(self, embed_limit)
#    1261 path = Path(tmpdir, "temp.m4v")
#    1262 # We create a writer manually so that we can get the
#    1263 # appropriate size for the tag
# -> 1264 Writer = writers[mpl.rcParams['animation.writer']]
#    1265 writer = Writer(codec='h264',
#    1266                 bitrate=mpl.rcParams['animation.bitrate'],
#    1267                 fps=1000. / self._interval)
#    1268 self.save(str(path), writer=writer)
#
# File D:\Anaconda\envs\Physics\lib\site-packages\matplotlib\animation.py:151, in MovieWriterRegistry.__getitem__(self, name)
#     149 if self.is_available(name):
#     150     return self._registered[name]
# --> 151 raise RuntimeError(f"Requested MovieWriter ({name}) not available")
#
# RuntimeError: Requested MovieWriter (ffmpeg) not available

# %% [markdown]
# **Histogramming:**

# %%
plt.hist(data_traj[0],range=(0,box[0]),bins=10)
plt.xlabel('position x')
plt.ylabel('occupancy')
plt.show()

# %%
plt.hist(data_traj[1],range=(0,box[1]),bins=10)
plt.xlabel('position y')
plt.ylabel('occupancy')
plt.show()

# %%
plt.hist2d(data_traj[0], data_traj[1], range=[[0,box[0]],[0,box[1]]], bins=10)
plt.xlabel('position x')
plt.ylabel('position y')
plt.colorbar().set_label('occupancy')
plt.show()

# %% [markdown]
# **Interpretation:**
# * in the reduced data projection, the occupancy of each bin seems even and well-distributed
# * in the full dimensional projection, it can be seen easily that the box is **not** fully sampled, large undersampled patches present
# * *data dimensionality reduction always brings the danger of wrong projection!*

# %% [markdown]
# **Solution for improvements:**
# * enhance sampling by
#     * prolong the simulation
#     * increase the time step
# * *Caveat: all solutions come with problems like increased computational cost or sampling errors!*
